# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\kushagra gemini\\Desktop\\census_income.csv")
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
print(df.head())
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
print(df.columns)
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 32555             0             0              38   United-States   <=50K
# 32556             0             0              40   United-States    >50K
# 32557             0             0              40   United-States   <=50K
# 32558             0             0              20   United-States   <=50K
# 32559         15024             0              40   United-States    >50K

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital_gain',
#  'Capital_loss',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %%
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Checking the value counts in each column
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Age
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: count, Length: 73, dtype: int64
#
#
# Workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64
#
#
# Fnlwgt
# 164190    13
# 203488    13
# 123011    13
# 148995    12
# 126675    12
#           ..
# 325573     1
# 140176     1
# 318264     1
# 329205     1
# 257302     1
# Name: count, Length: 21647, dtype: int64
#
#
# Education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: count, dtype: int64
#
#
# Education_num
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: count, dtype: int64
#
#
# Marital_status
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: count, dtype: int64
#
#
# Occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: count, dtype: int64
#
#
# Relationship
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: count, dtype: int64
#
#
# Race
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: count, dtype: int64
#
#
# Sex
#  Male      21789
#  Female    10771
# Name: count, dtype: int64
#
#
# Capital_gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: count, Length: 119, dtype: int64
#
#
# Capital_loss
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: count, Length: 92, dtype: int64
#
#
# Hours_per_week
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 82        1
# 94        1
# 92        1
# 74        1
# 87        1
# Name: count, Length: 94, dtype: int64
#
#
# Native_country
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: count, dtype: int64
#
#
# Income
#  <=50K    24719
#  >50K      7841
# Name: count, dtype: int64

# %%
df.Income.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df.Occupation.unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df.Sex.unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]>

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(df)

# %%
numeric_df = df.select_dtypes(include='number')

# Calculate correlation matrix
corr_hmap = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(16, 16))
sns.heatmap(corr_hmap, annot=True, cmap='coolwarm')
plt.show()

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week'], object: ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']}

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Fnlwgt'}>],
#        [<Axes: title={'center': 'Education_num'}>,
#         <Axes: title={'center': 'Capital_gain'}>],
#        [<Axes: title={'center': 'Capital_loss'}>,
#         <Axes: title={'center': 'Hours_per_week'}>]], dtype=object)

# %%
sns.countplot(y='Workclass', hue='Income', data=df)
# Out:
# <Axes: xlabel='count', ylabel='Workclass'>

# %%
sns.countplot(x='Sex', hue='Income', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(y='Occupation', hue='Income', data=df)
# Out:
# <Axes: xlabel='count', ylabel='Occupation'>

# %%
df['Hours_per_week'].plot.box()
# Out:
# <Axes: >

# %%
df['Capital_gain'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

categorical_features = list(df.select_dtypes(include=['object']).columns)
label_encoder_feat = {}
for i, feature in enumerate(categorical_features):
    label_encoder_feat[feature] = LabelEncoder()
    df[feature] = label_encoder_feat[feature].fit_transform(df[feature])

df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# 2              40              39       0
# 3              40               5       0
# 4              40              39       0

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
# Out:
# (32560, 15)

# %%
df1=df.loc[(z_score<3).all(axis=1)]
print(df1.shape)
# Out:
# (27417, 15)

# %%
df1.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 4   37          4  284582         12             14               2
# 5   49          4  160187          6              5               3
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 4           4             5     4    0             0             0
# 5           8             1     2    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0
# 2              40              39       0
# 4              40              39       0
# 5              16              23       0

# %%
df1.drop("Fnlwgt", axis=1,inplace=True)

# %%
df1.drop("Education", axis=1,inplace=True)

# %% [markdown]
# # Assigning x and y variables

# %%
df1.head(5)
# Out:
#    Age  Workclass  Education_num  Marital_status  Occupation  Relationship  \
# 0   50          6             13               2           4             0
# 1   38          4              9               0           6             1
# 2   53          4              7               2           6             0
# 4   37          4             14               2           4             5
# 5   49          4              5               3           8             1
#
#    Race  Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0     4    1             0             0              13              39
# 1     4    1             0             0              40              39
# 2     2    1             0             0              40              39
# 4     4    0             0             0              40              39
# 5     2    0             0             0              16              23
#
#    Income
# 0       0
# 1       0
# 2       0
# 4       0
# 5       0

# %%
df1.shape
# Out:
# (27417, 13)

# %%
x=df1.iloc[:,:12]
x.shape
# Out:
# (27417, 12)

# %%
y=df1.iloc[:,-1:]
y.shape
# Out:
# (27417, 1)

# %%
y.head()
# Out:
#    Income
# 0       0
# 1       0
# 2       0
# 4       0
# 5       0

# %% [markdown]
# # Standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler(copy=True, with_mean=True, with_std=True).fit(x)
df1_x_scaler = scaler.transform(x)
x = pd.DataFrame(df1_x_scaler)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.882739  1.474391  1.221891 -0.403219 -0.599291 -0.915305  0.344063
# 1 -0.011737  0.092844 -0.438259 -1.718982 -0.128090 -0.292911  0.344063
# 2  1.106358  0.092844 -1.268334 -0.403219 -0.128090 -0.915305 -2.961763
# 3 -0.086276  0.092844  1.636928 -0.403219 -0.599291  2.196663  0.344063
# 4  0.808199  0.092844 -2.098409  0.254663  0.343110 -0.292911 -2.961763
#
#          7         8         9         10        11
# 0  0.714839 -0.244885 -0.037453 -2.412190  0.193894
# 1  0.714839 -0.244885 -0.037453  0.008200  0.193894
# 2  0.714839 -0.244885 -0.037453  0.008200  0.193894
# 3 -1.398916 -0.244885 -0.037453  0.008200  0.193894
# 4 -1.398916 -0.244885 -0.037453 -2.143257 -5.661131

# %% [markdown]
# # MODEL SELECTION

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from scipy.stats import zscore
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # LINEAR REGRESSION

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.20,random_state=r_state)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score correspondint to: ",final_r_state,"is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42 is:  0.2744161387607318
# r2_score corresponding to random state:  43 is:  0.2686290561808802
# r2_score corresponding to random state:  44 is:  0.28483509561324905
# r2_score corresponding to random state:  45 is:  0.2880011975361966
# r2_score corresponding to random state:  46 is:  0.2868828203961773
# r2_score corresponding to random state:  47 is:  0.2920369967151162
# r2_score corresponding to random state:  48 is:  0.2750471798993379
# r2_score corresponding to random state:  49 is:  0.27779601741312976
# r2_score corresponding to random state:  50 is:  0.2800972084411215
# r2_score corresponding to random state:  51 is:  0.2752898938227162
# r2_score corresponding to random state:  52 is:  0.29119113480326086
# r2_score corresponding to random state:  53 is:  0.2788577194480145
# r2_score corresponding to random state:  54 is:  0.2635477054335118
# r2_score corresponding to random state:  55 is:  0.274201330507544
# r2_score corresponding to random state:  56 is:  0.2691931904195609
# r2_score corresponding to random state:  57 is:  0.2774768885105193
# r2_score corresponding to random state:  58 is:  0.27850307591761714
# r2_score corresponding to random state:  59 is:  0.2750209618460455
# r2_score corresponding to random state:  60 is:  0.2731791956762776
# r2_score corresponding to random state:  61 is:  0.28166501124981413
# r2_score corresponding to random state:  62 is:  0.28236230205313195
# r2_score corresponding to random state:  63 is:  0.28006745291165547
# r2_score corresponding to random state:  64 is:  0.27596646825257487
# r2_score corresponding to random state:  65 is:  0.27752711857825596
# r2_score corresponding to random state:  66 is:  0.2763079566730927
# r2_score corresponding to random state:  67 is:  0.28349297453703415
# r2_score corresponding to random state:  68 is:  0.26809059999450113
# r2_score corresponding to random state:  69 is:  0.2792756874646438
# r2_score corresponding to random state:  70 is:  0.27615545084189375
# r2_score corresponding to random state:  71 is:  0.2473356583992884
# r2_score corresponding to random state:  72 is:  0.2772372266284623
# r2_score corresponding to random state:  73 is:  0.2788139673348059
# r2_score corresponding to random state:  74 is:  0.25886802474618664
# r2_score corresponding to random state:  75 is:  0.2907946647073484
# r2_score corresponding to random state:  76 is:  0.2892958085057299
# r2_score corresponding to random state:  77 is:  0.2766725417625394
# r2_score corresponding to random state:  78 is:  0.2783504129165889
# r2_score corresponding to random state:  79 is:  0.29233389836915424
# r2_score corresponding to random state:  80 is:  0.28311853911773477
# r2_score corresponding to random state:  81 is:  0.2888062737664223
# r2_score corresponding to random state:  82 is:  0.2727200693293923
# r2_score corresponding to random state:  83 is:  0.28725574419066735
# r2_score corresponding to random state:  84 is:  0.30290083490900677
# r2_score corresponding to random state:  85 is:  0.28365502987455804
# r2_score corresponding to random state:  86 is:  0.2599288426676518
# r2_score corresponding to random state:  87 is:  0.2750235625744003
# r2_score corresponding to random state:  88 is:  0.27838218299200457
# r2_score corresponding to random state:  89 is:  0.2870336703753614
# r2_score corresponding to random state:  90 is:  0.28097776129829033
# r2_score corresponding to random state:  91 is:  0.26540635564813475
# r2_score corresponding to random state:  92 is:  0.2753881962669562
# r2_score corresponding to random state:  93 is:  0.28337571975448395
# r2_score corresponding to random state:  94 is:  0.27960217031238244
# r2_score corresponding to random state:  95 is:  0.2756681654027333
# r2_score corresponding to random state:  96 is:  0.2773942242473878
# r2_score corresponding to random state:  97 is:  0.276607465033046
# r2_score corresponding to random state:  98 is:  0.2836621951085927
# r2_score corresponding to random state:  99 is:  0.27462593228543775
#
#
# max r2_score correspondint to:  84 is  0.30290083490900677

# %% [markdown]
# LASSO

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
isreh=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
grid=GridSearchCV(isreh,parameters,cv=10)
grid.fit(x,y)
grid.best_params_
# Out:
# {'alpha': 0.001}

# %%
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.20,random_state=r_state)
    lasso=Lasso(alpha=0.01)
    lasso.fit(x_train,y_train)
    y_pred=lasso.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random state: ",r_state,"is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print()
print("max r2_score correspondint to: ",final_r_state,"is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42 is:  0.27183618868833725
# r2_score corresponding to random state:  43 is:  0.267323134004541
# r2_score corresponding to random state:  44 is:  0.2795573015888506
# r2_score corresponding to random state:  45 is:  0.2833357428452319
# r2_score corresponding to random state:  46 is:  0.2819515914001637
# r2_score corresponding to random state:  47 is:  0.2879336060236499
# r2_score corresponding to random state:  48 is:  0.27343335413204783
# r2_score corresponding to random state:  49 is:  0.2764307031821188
# r2_score corresponding to random state:  50 is:  0.2747309190693291
# r2_score corresponding to random state:  51 is:  0.2727910716652109
# r2_score corresponding to random state:  52 is:  0.2871773854507209
# r2_score corresponding to random state:  53 is:  0.27591261152602475
# r2_score corresponding to random state:  54 is:  0.2597076342676272
# r2_score corresponding to random state:  55 is:  0.27184139098257887
# r2_score corresponding to random state:  56 is:  0.2672161925006926
# r2_score corresponding to random state:  57 is:  0.273296028722812
# r2_score corresponding to random state:  58 is:  0.27592907038395176
# r2_score corresponding to random state:  59 is:  0.27071279404607496
# r2_score corresponding to random state:  60 is:  0.2718613939871438
# r2_score corresponding to random state:  61 is:  0.2791228585208494
# r2_score corresponding to random state:  62 is:  0.2814204238599497
# r2_score corresponding to random state:  63 is:  0.27789734330436877
# r2_score corresponding to random state:  64 is:  0.2727293113039233
# r2_score corresponding to random state:  65 is:  0.27439298999622075
# r2_score corresponding to random state:  66 is:  0.27265084589992294
# r2_score corresponding to random state:  67 is:  0.28107658115928313
# r2_score corresponding to random state:  68 is:  0.26563748408906107
# r2_score corresponding to random state:  69 is:  0.27733440953929
# r2_score corresponding to random state:  70 is:  0.2732210267208631
# r2_score corresponding to random state:  71 is:  0.2467982353919308
# r2_score corresponding to random state:  72 is:  0.2743853947179251
# r2_score corresponding to random state:  73 is:  0.2756268966048674
# r2_score corresponding to random state:  74 is:  0.25941980300157663
# r2_score corresponding to random state:  75 is:  0.2877357734723439
# r2_score corresponding to random state:  76 is:  0.28592230424556764
# r2_score corresponding to random state:  77 is:  0.2740828689830117
# r2_score corresponding to random state:  78 is:  0.2759006339368303
# r2_score corresponding to random state:  79 is:  0.2885218168964585
# r2_score corresponding to random state:  80 is:  0.2803337011039848
# r2_score corresponding to random state:  81 is:  0.2859929072953862
# r2_score corresponding to random state:  82 is:  0.26909123298326765
# r2_score corresponding to random state:  83 is:  0.2837451745632915
# r2_score corresponding to random state:  84 is:  0.29766025788420525
# r2_score corresponding to random state:  85 is:  0.27861260249019715
# r2_score corresponding to random state:  86 is:  0.25821288841197065
# r2_score corresponding to random state:  87 is:  0.2709778454392311
# r2_score corresponding to random state:  88 is:  0.2765874341603942
# r2_score corresponding to random state:  89 is:  0.2839673336734292
# r2_score corresponding to random state:  90 is:  0.28000895122723723
# r2_score corresponding to random state:  91 is:  0.2626106758879698
# r2_score corresponding to random state:  92 is:  0.2714323248505133
# r2_score corresponding to random state:  93 is:  0.27965291979891393
# r2_score corresponding to random state:  94 is:  0.27629342219785424
# r2_score corresponding to random state:  95 is:  0.2719893607814098
# r2_score corresponding to random state:  96 is:  0.2750687112679012
# r2_score corresponding to random state:  97 is:  0.2749194278308972
# r2_score corresponding to random state:  98 is:  0.27983093894558053
# r2_score corresponding to random state:  99 is:  0.27115211387391425
#
#
# max r2_score correspondint to:  84 is  0.29766025788420525

# %% [markdown]
# # Logistic Regression

# %%
#shape of old and new data frame
print('Old Data Frame -',df.shape[0])
print('New Data Frame -',df2.shape[0])

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.20,random_state=42,stratify=y)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (21933, 12) (5484, 12)
# (21933, 1) (5484, 1)

# %%
from sklearn.svm import SVC
LOR=LogisticRegression()
GNB=GaussianNB()
SVC=SVC()
DTC=DecisionTreeClassifier(random_state=10)
KNN=KNeighborsClassifier()

# %%
models= []
models.append(('LogisticRegression',LOR))
models.append(('GaussianNB',GNB))
models.append(('SVC',SVC))
models.append(('DecisionTreeClassifier',DTC))
models.append(('KNeighborsClassifie',KNN))

# %%
Model = []
score = []
cvs = []
rocscore = []
for name,model in models:
    print('====================',name,'=======================')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print('\n')
    AS= accuracy_score(y_test,pred)
    print('ACCURACY SCORE IS = ',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('CROSS_VAL_SCORE = ',sc)
    cvs.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('ROC_AUC_SCORE = ',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('CLASSIFICATION REPORT = ',classification_report(y_test,pred))
    print('\n')
    cm=confusion_matrix(y_test,pred)
    print('CONFUSION MATRIX',cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'k--')
    plt.plot(false_positive_rate,true_positive_rate,label='AUC= %.2f'% roc_auc)
    plt.xlabel('false positive rate')
    plt.ylabel('true positive rate')
    plt.title(name)
    plt.show()
    print('\n\n')
# Out:
# ==================== LogisticRegression =======================
#
#
# LogisticRegression()
#
#
# ACCURACY SCORE IS =  0.8269511305616338
#
#
# CROSS_VAL_SCORE =  0.8295585632549572
#
#
# ROC_AUC_SCORE =  0.6863102636477186
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89      4256
#            1       0.68      0.43      0.53      1228
#
#     accuracy                           0.83      5484
#    macro avg       0.77      0.69      0.71      5484
# weighted avg       0.81      0.83      0.81      5484
#
#
#
# CONFUSION MATRIX [[4005  251]
#  [ 698  530]]
#
#
# Axes(0.125,0.807358;0.62x0.0726415)
# ==================== GaussianNB =======================
#
#
# GaussianNB()
#
#
# ACCURACY SCORE IS =  0.8037928519328957
#
#
# CROSS_VAL_SCORE =  0.7937785514345602
#
#
# ROC_AUC_SCORE =  0.7742282977394627
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      4256
#            1       0.55      0.72      0.62      1228
#
#     accuracy                           0.80      5484
#    macro avg       0.73      0.77      0.74      5484
# weighted avg       0.83      0.80      0.81      5484
#
#
#
# CONFUSION MATRIX [[3523  733]
#  [ 343  885]]
#
#
# Axes(0.125,0.807358;0.62x0.0726415)
# ==================== SVC =======================
#
#
# SVC()
#
#
# ACCURACY SCORE IS =  0.8590444930707513
#
#
# CROSS_VAL_SCORE =  0.8506769186391056
#
#
# ROC_AUC_SCORE =  0.7359554474541401
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      4256
#            1       0.78      0.51      0.62      1228
#
#     accuracy                           0.86      5484
#    macro avg       0.83      0.74      0.77      5484
# weighted avg       0.85      0.86      0.85      5484
#
#
#
# CONFUSION MATRIX [[4081  175]
#  [ 598  630]]
#
#
# Axes(0.125,0.807358;0.62x0.0726415)
# ==================== DecisionTreeClassifier =======================
#
#
# DecisionTreeClassifier(random_state=10)
#
#
# ACCURACY SCORE IS =  0.8187454412837345
#
#
# CROSS_VAL_SCORE =  0.809826203973431
#
#
# ROC_AUC_SCORE =  0.7392502785873479
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      4256
#            1       0.60      0.60      0.60      1228
#
#     accuracy                           0.82      5484
#    macro avg       0.74      0.74      0.74      5484
# weighted avg       0.82      0.82      0.82      5484
#
#
#
# CONFUSION MATRIX [[3759  497]
#  [ 497  731]]
#
#
# Axes(0.125,0.807358;0.62x0.0726415)
# ==================== KNeighborsClassifie =======================
#
#
# KNeighborsClassifier()
#
#
# ACCURACY SCORE IS =  0.8475565280816922
#
#
# CROSS_VAL_SCORE =  0.8369626369544143
#
#
# ROC_AUC_SCORE =  0.7636060070779556
#
#
# CLASSIFICATION REPORT =                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      4256
#            1       0.68      0.61      0.64      1228
#
#     accuracy                           0.85      5484
#    macro avg       0.78      0.76      0.77      5484
# weighted avg       0.84      0.85      0.84      5484
#
#
#
# CONFUSION MATRIX [[3897  359]
#  [ 477  751]]
#
#
# Axes(0.125,0.807358;0.62x0.0726415)

# %%
result=pd.DataFrame({'Model': Model,'Accuracy_score': score,'Cross_val_score': cvs,'Roc_auc_curve': rocscore})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score  Roc_auc_curve
# 0      LogisticRegression       82.695113        82.955856      68.631026
# 1              GaussianNB       80.379285        79.377855      77.422830
# 2                     SVC       85.904449        85.067692      73.595545
# 3  DecisionTreeClassifier       81.874544        80.982620      73.925028
# 4     KNeighborsClassifie       84.755653        83.696264      76.360601

# %% [markdown]
# SVC is the bestmodel for this datset so far

# %%
print('Mean absolute error : ',mean_absolute_error(y_test,y_pred))
print('Mean Squared error : ',mean_squared_error(y_test,y_pred))
print("RMSE is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean absolute error :  0.3554134939123763
# Mean Squared error :  0.21134058358953273
# RMSE is :  0.4597179391643671

# %% [markdown]
# When your accuracy score is not up to the mark and in order to increase the accuracy score we are going to use here RANDOM FOREST REGRESSOR and GRADIENT BOOSTING REGRESSOR in order to increase the score for the above tests.
#
# The boosting and bagging techniques will re enable or boost the internal parameters inorder to increase the accuracy score of the model.

# %%
from math import log
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
estimator = RandomForestRegressor()
param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=5)

grid.fit(x_train, y_train)

grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'log2',
#  'min_samples_split': 8,
#  'n_estimators': 30}

# %% [markdown]
# # K-MEANS CLUSTERING

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=3)
kModel=kmeans.fit(df1)

# %%
kModel.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
pd.crosstab(df1.Income,kModel.labels_)
# Out:
# col_0       0    1    2
# Income
# 0       20739  534    6
# 1        4819  834  485

# %%
from sklearn.metrics import homogeneity_score

# %%
print(homogeneity_score(kModel.labels_,df1.Income))
# Out:
# 0.15996919689664865

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
R_forest= RandomForestClassifier(n_estimators = 100)
modelR= R_forest.fit(x_train, y_train)

# Predictions
pred_2 = modelR.predict(x_test)

print ("The accuracy of model 2 : ",accuracy_score(y_test, pred_2))
print ("The f1 score of model 2 : ", f1_score(y_test, pred_2, average = 'binary'))
# Out:
# The accuracy of model 2 :  0.8557622173595916
# The f1 score of model 2 :  0.6606606606606606

# %% [markdown]
# # SAVING THE MODEL

# %%
import pickle

filename = 'census_income.pkl'

pickle.dump(SVC, open(filename, 'wb'))

# %%
#Pridicting x_test
SVC.predict(x_test)
# Out:
# array([0, 0, 0, ..., 1, 0, 0])
